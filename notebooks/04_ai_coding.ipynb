# %% [markdown]
# # Modul 4 — AI-assisted coding cu Python
# **DELTA-Hub Workshop · 23 mai 2026**
#
# Notebook de lucru pentru sesiunea hands-on.
#
# ---

# %%
# Instalare pachete
# !pip install -q numpy pandas matplotlib xarray zarr plotly
import warnings; warnings.filterwarnings('ignore')
print('✓ Pachete instalate.')

# %% [markdown]
# ---
# ## Exercițiu 1

# %%
# Cod generat cu AI

# %% [markdown]
# ---
# ## Exercițiu 2

# %%
# Cod generat cu AI

# %% [markdown]
# ---
# ## Exercițiu 3

# %%
# Cod generat cu AI

# %% [markdown]
# ---
# ## Note personale
#
# *(adaugă observații, link-uri utile, prompturi care au funcționat)*
